# %% [markdown]
# # Waldo vs Not Waldo Classification (Oversampling Minority)
#
# Thanks to __, we have a dataset of __ images of either Waldo or not Waldo of varying sizes and color. In this project, we will use various model architecture to classify these images as either Waldo or not Waldo.
#
# https://medium.com/bitgrit-data-science-publication/building-an-image-classification-model-with-pytorch-from-scratch-f10452073212

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (3.9.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2.2.2)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.5.0)
# Collecting imblearn (from -r requirements.txt (line 7))
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (4.12.1)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch->-r requirements.txt (line 1)) (2024.6.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torchvision->-r requirements.txt (line 2)) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 6)) (3.5.0)
# Collecting imbalanced-learn (from imblearn->-r requirements.txt (line 7))
#   Downloading imbalanced_learn-0.12.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->torch->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sympy->torch->-r requirements.txt (line 1)) (1.3.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.12.3-py3-none-any.whl (258 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 6.5 MB/s eta 0:00:0000:01
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.12.3 imblearn-0.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Frameworks/Python.framework/Versions/3.12/bin/python3.12 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import torch.nn.functional as F
import numpy as np
from numpy import random
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import pandas as pd
from torchvision.io import read_image
from sklearn.model_selection import train_test_split

from PIL import Image

# %%
random.seed(10)
torch.manual_seed(2502655302062314811)
SIZE = 64
NOTWALDO = f'Hey-Waldo/{SIZE}/notwaldo'
WALDO = f'Hey-Waldo/{SIZE}/waldo'

# %% [markdown]
# ### Preliminary Data Exploration

# %%
nrows, ncols = 4, 4

ig, ax = plt.subplots(nrows,ncols,figsize = (10,10))
ax = ax.flatten()

for i in range(nrows*ncols):
  if i < 8:
    pic = plt.imread(NOTWALDO + '/' + os.listdir(NOTWALDO)[i%8])
    ax[i].imshow(pic)
    ax[i].set_axis_off()
  else:
    pic = plt.imread(WALDO + '/' + os.listdir(WALDO)[i%8])
    ax[i].imshow(pic)
    ax[i].set_axis_off()
plt.show()

# %% [markdown]
# # Creating Dataset

# %% [markdown]
# Because there is an imbalance in the dataset, we will try

# %%
# convert images to torch tensors 
read_img = transforms.Compose([transforms.PILToTensor()])

notwaldo = []
waldo = []
img_labels = []

for i in os.listdir(NOTWALDO):
    img_labels.append(['notwaldo/' + i, 0])
    image = Image.open(NOTWALDO + '/' + i)
    notwaldo.append(read_img(image))

for i in os.listdir(WALDO):
    img_labels.append(['waldo/' + i, 1])
    image = Image.open(WALDO + '/' + i)
    
    waldo.append(read_img(image))

# %%
df = pd.DataFrame(img_labels, columns=['fname', 'label'])

train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['label'], random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.25, stratify=train_df['label'], random_state=42)

train_df.to_csv('img_labels_train.csv', index=False)
val_df.to_csv('img_labels_val.csv', index=False)
test_df.to_csv('img_labels_test.csv', index=False)

# %%
class_counts = train_df.label.value_counts()

class_weights = 1 / class_counts

sample_weights = [1/class_counts[i] for i in train_df.label.values]

# %%
print( f'waldo images: {len(os.listdir(WALDO))}, not waldo images: {len(os.listdir(NOTWALDO))}')
# Out:
# waldo images: 39, not waldo images: 5337

# %%
class WaldoDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = read_image(img_path)
        label = self.img_labels.iloc[idx, 1]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
transform = transforms.Compose( # composing several transforms together
    [transforms.ToPILImage(), # to tensor object
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) # mean = 0.5, std = 0.5
     ])

batch_size = 8
num_workers = 0

sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(df), replacement=True)

trainset = WaldoDataset(annotations_file='img_labels_train.csv', img_dir=f'Hey-Waldo/{SIZE}', transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)

valset = WaldoDataset(annotations_file='img_labels_val.csv', img_dir=f'Hey-Waldo/{SIZE}', transform=transform)
valloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=num_workers)

testset = WaldoDataset(annotations_file='img_labels_test.csv', img_dir=f'Hey-Waldo/{SIZE}', transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %%
def imshow(img):
  ''' function to show image '''
  img = img / 2 + 0.5 # unnormalize
  npimg = img.numpy() # convert to numpy objects
  plt.imshow(np.transpose(npimg, (1, 2, 0)))
  plt.show()

# %%
dataiter = iter(trainloader)
images, labels = next(dataiter)
classes = ['Not Waldo', 'Waldo']

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%s |' % classes[labels[j]] for j in range(8)))
# Out:
# GroundTruth:  Waldo | Not Waldo | Waldo | Waldo | Not Waldo | Waldo | Waldo | Not Waldo |

# %% [markdown]
# # Using simple CNN architecture

# %%
class Net(nn.Module):
    ''' Models a simple Convolutional Neural Network'''
	
    def __init__(self):
        super(Net, self).__init__()
	# 3 input image channel, 6 output channels, 
	# 5x5 square convolution kernel
        self.conv1 = nn.Conv2d
# [2, 270] loss: 0.016
# [2, 280] loss: 0.043
# [2, 290] loss: 0.018
# [2, 300] loss: 0.012
# [2, 310] loss: 0.026
# [2, 320] loss: 0.016
# [2, 330] loss: 0.015
# [2, 340] loss: 0.015
# [2, 350] loss: 0.017
# [2, 360] loss: 0.016
# [2, 370] loss: 0.011
# [2, 380] loss: 0.009
# [2, 390] loss: 0.015
# [2, 400] loss: 0.025
# [2, 410] loss: 0.013
# [2, 420] loss: 0.009
# [2, 430] loss: 0.012
# [2, 440] loss: 0.010
# [2, 450] loss: 0.034
# [2, 460] loss: 0.011
# [2, 470] loss: 0.006
# [2, 480] loss: 0.008
# [2, 490] loss: 0.009
# [2, 500] loss: 0.007
# [2, 510] loss: 0.004
# [2, 520] loss: 0.021
# [2, 530] loss: 0.010
# [2, 540] loss: 0.031
# [2, 550] loss: 0.008
# [2, 560] loss: 0.060
# [2, 570] loss: 0.018
# [2, 580] loss: 0.007
# [2, 590] loss: 0.008
# [2, 600] loss: 0.003
# [2, 610] loss: 0.026
# [2, 620] loss: 0.010
# [2, 630] loss: 0.017
# [2, 640] loss: 0.010
# [2, 650] loss: 0.004
# [2, 660] loss: 0.004
# [2, 670] loss: 0.011
# Finished Training

# %% [markdown]
# # Test

# %%
# without any image augmentation

correct = 0
total = 0
with torch.no_grad():
    for data in valloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on test images: 98 %

# %% [markdown]
# # Adding image augmentation

# %%
transform_aug = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(5),
    transforms.RandomResizedCrop(64, scale=(0.8, 1.0)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

batch_size = 8
num_workers = 0

sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(df), replacement=True)

trainset = WaldoDataset(annotations_file='img_labels_train.csv', img_dir=f'Hey-Waldo/{SIZE}', transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, sampler=sampler, num_workers=num_workers)

# load test data
testset = WaldoDataset(annotations_file='img_labels_test.csv', img_dir=f'Hey-Waldo/{SIZE}', transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=num_workers)

# %%
# start = torch.cuda.Event(enable_timing=True)
# end = torch.cuda.Event(enable_timing=True)
# start.record()
net = Net()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

losses = []
for epoch in range(2):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        
        # print statistics
        running_loss += loss.item()
        if i % 10 == 9:    # print every 10 mini-batches
            # print('[%d, %d] loss: %.3f' %
            #       (epoch + 1, i + 1, running_loss / 10))
            losses.append(running_loss / 10)
            running_loss = 0.0

# # whatever you are timing goes here
# end.record()

# # Waits for everything to finish running
# torch.cuda.synchronize()
print('Finished Training')
plt.plot(losses)
plt.title('Running Loss')
plt.show()
# print(start.elapsed_time(end))  # milliseconds
# Out:
# Finished Training

# %%
# with any image augmentation

correct = 0
total = 0
with torch.no_grad():
    for data in valloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on test images: 98 %

# %% [markdown]
# # Increasing depth

# %%
class ModifiedNet(nn.Module):
    ''' Modified Convolutional Neural Network'''
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1) # add a third conv layer
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 8 * 8, 512)
        self.fc2 = nn.Linear(512, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 64 * 8 * 8)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
net = Net()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

losses = []
for epoch in range(250):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        
        # print statistics
        running_loss += loss.item()
        if i % 10 == 9:    # print every 10 mini-batches
            # print('[%d, %d] loss: %.3f' %
            #       (epoch + 1, i + 1, running_loss / 10))
            losses.append(running_loss / 10)
            running_loss = 0.0

# # whatever you are timing goes here
# end.record()

# # Waits for everything to finish running
# torch.cuda.synchronize()
print('Finished Training')
plt.plot(losses)
plt.title('Running Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 net = Net()
#       3 criterion = nn.CrossEntropyLoss()
#       4 optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
#
# NameError: name 'Net' is not defined

# %%
# image augmentation + 

correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on test images: %d %%' % (
    100 * correct / total))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 correct = 0
#       4 total = 0
# ----> 5 with torch.no_grad():
#       6     for data in testloader:
#       7         images, labels = data
#
# NameError: name 'torch' is not defined

# %%
from imblearn.over_sampling import RandomOverSampler

train_images_reshaped = np.array(train_images).reshape((len(train_images), -1))

ros = RandomOverSampler(random_state=42)
train_images_resampled, train_labels_resampled = ros.fit_resample(train_images_reshaped, train
                                                                  
train_images_resampled = train_images_resampled.reshape((-1, image_height, image_width, num_channels))
